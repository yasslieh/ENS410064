# %% [markdown]
# # ETAPA 2

# %% [markdown]
# ## Numpy arrays

# %%
import numpy as np

# cria uma matriz de dados aleatórios de 1000 linhas e 2 colunas
data = np.random.rand(1000,2)

# pra ver quantas linhas, colunas e valores tem na amtriz
print(data.shape)
print(np.size(data))

# Print das 10 primeiras linhas
print(data[0:10])
print(data[0:10].shape)
# Out:
# (1000, 2)
# 2000
# [[0.75637851 0.94011889]
#  [0.41128344 0.03516493]
#  [0.00790073 0.99982556]
#  [0.7518016  0.67583784]
#  [0.12108455 0.47697063]
#  [0.62980593 0.21326879]
#  [0.06663936 0.13371962]
#  [0.19169332 0.58593146]
#  [0.96297235 0.95715329]
#  [0.57795286 0.5107848 ]]
# (10, 2)

# %%
# Usando Monte-Carlo
dataMax = 1000
dataMin = 10
data = (dataMax - dataMin)*data + dataMin
print(data[0:10])
#faz com que os valores da matriz estejam entre 10 e 1000
# Out:
# [[758.81472956 940.71769839]
#  [417.17061023  44.81328414]
#  [ 17.82172202 999.82730231]
#  [754.28358068 679.07945933]
#  [129.87370258 482.20092818]
#  [633.50786707 221.13610551]
#  [ 75.97296777 142.38242423]
#  [199.77639165 590.07214304]
#  [963.34262606 957.58175633]
#  [582.17333629 515.67694842]]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3)
ax[0].plot(data)
ax[1].plot(data[:,0])
ax[2].plot(data[:,1])
print(type(data))
#usa a biblioteca matplotlib para visualizar em forma de gráfico a matriz
#o (3) indica que serão 3 linhas de gráfico
#o primeiro gráfico plota todos os valores da amtriz, o segundo plota toda a primeira coluna e o último plota a segunda coluna
# Out:
# <class 'numpy.ndarray'>

# %%
# Criando um dado 2D 
data3d = np.sin(np.random.rand(1000,1000))
print(data3d)
#o np.sin faz com que todos os valores sejam seno de um número entre 0 e 1
# Out:
# [[0.7083651  0.18221082 0.65846967 ... 0.6851747  0.72708172 0.6885275 ]
#  [0.81145456 0.29732192 0.20049694 ... 0.14893722 0.74771554 0.13985442]
#  [0.80412616 0.65743748 0.46339897 ... 0.23876993 0.77632344 0.51893001]
#  ...
#  [0.72897639 0.0822926  0.62068463 ... 0.77613852 0.40616671 0.26733437]
#  [0.33939307 0.40636007 0.63875089 ... 0.51412877 0.37219495 0.31230009]
#  [0.44903827 0.28606024 0.46555032 ... 0.63860249 0.00309691 0.11516643]]

# %%
# Plotando um dado 3D
fig2, ax2 = plt.subplots()
ax2.pcolor(data3d)
#dessa vez cria só um plot usando o pcolor onde cada valor é representado por uma cor

# %%
# Criando vertor temporal
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01"), np.timedelta64(1, "h"))
print(dtime[1:10])
print(dtime.shape)
print(type(dtime))
#criação de uma matriz de tempo
#data inicial - data final -intervalo em horas
# Out:
# ['2022-01-01T01' '2022-01-01T02' '2022-01-01T03' '2022-01-01T04'
#  '2022-01-01T05' '2022-01-01T06' '2022-01-01T07' '2022-01-01T08'
#  '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# Criando um dataframe
df = pd.DataFrame()
#dataframe é como se fosse uma planilha, usamos a biblioteca Pandas pra criar tabelas

# %%
# Monstrando um dataframe
df['datetime'] = dtime
#adiciona uma coluna na matriz
#a coluna adicionada é a temporal criada anteriormente

# %%
# Criando uma coluna random dentro do dataframe df
df['random'] = np.random.rand(df.shape[0])
#cria de outra coluna, só que aleatória
#o df.shape faz com que essa coluna nova tenha a mesma quantidade de linhas que o dataframe

# %%
df['random'][1:10]
#mostrando 9 linhas só da coluna random
# Out:
# 1    0.616287
# 2    0.480745
# 3    0.140316
# 4    0.819462
# 5    0.833449
# 6    0.849788
# 7    0.393847
# 8    0.255016
# 9    0.944214
# Name: random, dtype: float64

# %%
# Indexação
df.iloc[:,0]
#iloc para acessar os valores pelo indice
#acessando todos os valores da primeira coluna do df
# Out:
# 0      2022-01-01 00:00:00
# 1      2022-01-01 01:00:00
# 2      2022-01-01 02:00:00
# 3      2022-01-01 03:00:00
# 4      2022-01-01 04:00:00
#                ...
# 8755   2022-12-31 19:00:00
# 8756   2022-12-31 20:00:00
# 8757   2022-12-31 21:00:00
# 8758   2022-12-31 22:00:00
# 8759   2022-12-31 23:00:00
# Name: datetime, Length: 8760, dtype: datetime64[s]

# %%
# Colocando o datetime como index
df = df.set_index(df['datetime'])
df
#colocando a coluna datetime como indice do df
#só precisa colocar df pra ver, sem print
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.818094
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.616287
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.480745
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.140316
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.819462
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.134331
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.291784
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.475377
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.998254
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.880292
#
# [8760 rows x 2 columns]

# %%
# Criando colunas com ano, mês e dia
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
#cria três colunas, pegando do datetime ficam uma para ano, uma para mês e uma para dia

# %%
tt = np.arange(0,df.shape[0],1)
print(tt.shape)
df['sazonal'] = (np.cos(tt/(360*4)))
df['timeSeries'] = 10*df['sazonal']+df['random']
#df['sazonal'].plot()
df['timeSeries'].plot(color='red')
#cria uma matriz nova, argumentos (vai de, até, ao passo de)
#cria 2 colunas novas, a primeira são cossenos, segunda soma e aumenta em 10x os valores de duas colunas
#plota gráfico na cor vermelho
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %%
df
#print do dataframe
# Out:
#                                datetime    random  year  month  day   sazonal  \
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.818094  2022      1    1  1.000000
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.616287  2022      1    1  1.000000
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.480745  2022      1    1  0.999999
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.140316  2022      1    1  0.999998
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.819462  2022      1    1  0.999996
# ...                                 ...       ...   ...    ...  ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.134331  2022     12   31  0.979401
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.291784  2022     12   31  0.979541
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.475377  2022     12   31  0.979680
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.998254  2022     12   31  0.979819
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.880292  2022     12   31  0.979958
#
# ...

# %%
# Salvar meu dataframe

df.to_csv(r'C:\UFSC\ENS410064\dados\brutos\noise_2022.csv')

# %%
# Criando uma função
#tudo que estiver dentro da função faz parte e no fim precisa ter return de algo
def noiseCreation(path, year):
    """Esta função cria um ruido com sazonalidade.
    Inputs:
        path = asdasdas
        year = asdasdasdas

    Criado por Leonardo
    """
    
    # Criando um dataframe
    df = pd.DataFrame()
    
    # Criando vertor temporal
    #aqui usa a variável year da função
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year+1)+"-01-01"), np.timedelta64(1, "h"))
    
    # cria uma coluna com os dados temporais
    df['datetime'] = dtime
        
    # Datetime como index do dataframe
    df = df.set_index(df['datetime'])
    
    # Criando colunas com ano, mês e dia
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day
    
    # Crio uma coluna random
    df['random'] = np.random.rand(df.shape[0])
    
    # Adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1)
    print(tt.shape)
    df['sazonal'] = (np.cos(tt/(360*4)))
    df['timeSeries'] = 10*df['sazonal']+df['random']
    #df['sazonal'].plot()
    df['timeSeries'].plot(color='red')
    df.to_csv(path+'/noise_'+str(year)+'.csv')
    
    return df
#basicamente é uma função que faz o que foi feito nas linhas acima
#só precisa fornecer o ano para os dados e o diretório para salvar o dataframe

# %%
path = r'C:\UFSC\ENS410064\dados\brutos'
df2 = noiseCreation(path,2050)
#realiza a função acima para o ano de 2050
# Out:
# (8760,)

# %%
# Primeira opção de loop
for ii in range(2002,2010):
    print(ii)
    df = noiseCreation(path,ii)
#o loop itera a função noiseCreation desde 2002 até 2010, dando como return 8 planilhas no diretório escolhido
# Out:
# 2002
# (8760,)
# 2003
# (8760,)
# 2004
# (8784,)
# 2005
# (8760,)
# 2006
# (8760,)
# 2007
# (8760,)
# 2008
# (8784,)
# 2009
# (8760,)

# %%
df
#mostra o dataframe
# Out:
#                                datetime  year  month  day    random   sazonal  \
# datetime
# 2009-01-01 00:00:00 2009-01-01 00:00:00  2009      1    1  0.849995  1.000000
# 2009-01-01 01:00:00 2009-01-01 01:00:00  2009      1    1  0.595506  1.000000
# 2009-01-01 02:00:00 2009-01-01 02:00:00  2009      1    1  0.094532  0.999999
# 2009-01-01 03:00:00 2009-01-01 03:00:00  2009      1    1  0.449995  0.999998
# 2009-01-01 04:00:00 2009-01-01 04:00:00  2009      1    1  0.989823  0.999996
# ...                                 ...   ...    ...  ...       ...       ...
# 2009-12-31 19:00:00 2009-12-31 19:00:00  2009     12   31  0.669580  0.979401
# 2009-12-31 20:00:00 2009-12-31 20:00:00  2009     12   31  0.032175  0.979541
# 2009-12-31 21:00:00 2009-12-31 21:00:00  2009     12   31  0.695332  0.979680
# 2009-12-31 22:00:00 2009-12-31 22:00:00  2009     12   31  0.341477  0.979819
# 2009-12-31 23:00:00 2009-12-31 23:00:00  2009     12   31  0.944024  0.979958
#
# ...

# %%
#primeiro cria uma lista com anos
anos = [2001,2030,2032,2053,2060]
#começa o loop
for ano in anos:
    print(ano) #mostra o ano que está sendo feita a função
    if ano > 2030: #verificação, só entra na função se o ano for maior que 2030
        df = noiseCreation(path,ano)
# Out:
# 2001
# 2030
# 2032
# (8784,)
# 2053
# (8760,)
# 2060
# (8784,)

# %%
import os #biblioteca os serve para navegar ou interagir com o sistema opetacional (operational system)
files = os.listdir(path) #cria uma lista com os arquivos no diretório path
print(files)

allData = [] #lista vazia
for file in files: #loop
    if file.endswith('.csv'): #verificação, endswith para ver a terminação do arquivo
        print(file) #só vai printar se for .csv
        data = pd.read_csv(path+'/'+file) #lê o csv
        allData.append(data) #adiciona na lista o df lido
# Out:
# ['noise_2002.csv', 'noise_2003.csv', 'noise_2004.csv', 'noise_2005.csv', 'noise_2006.csv', 'noise_2007.csv', 'noise_2008.csv', 'noise_2009.csv', 'noise_2022.csv', 'noise_2032.csv', 'noise_2050.csv', 'noise_2053.csv', 'noise_2060.csv']
# noise_2002.csv
# noise_2003.csv
# noise_2004.csv
# noise_2005.csv
# noise_2006.csv
# noise_2007.csv
# noise_2008.csv
# noise_2009.csv
# noise_2022.csv
# noise_2032.csv
# noise_2050.csv
# noise_2053.csv
# noise_2060.csv

# %%
allDataDf = pd.concat(allData) #concatena todos os df armazenados na lista criada em um df só

# %%
allDataDf #mostra o df novo que combina todos os anteriores
# Out:
#                  datetime           datetime.1  year  month  day    random  \
# 0     2002-01-01 00:00:00  2002-01-01 00:00:00  2002      1    1  0.422338
# 1     2002-01-01 01:00:00  2002-01-01 01:00:00  2002      1    1  0.105085
# 2     2002-01-01 02:00:00  2002-01-01 02:00:00  2002      1    1  0.808033
# 3     2002-01-01 03:00:00  2002-01-01 03:00:00  2002      1    1  0.736821
# 4     2002-01-01 04:00:00  2002-01-01 04:00:00  2002      1    1  0.321028
# ...                   ...                  ...   ...    ...  ...       ...
# 8779  2060-12-31 19:00:00  2060-12-31 19:00:00  2060     12   31  0.588779
# 8780  2060-12-31 20:00:00  2060-12-31 20:00:00  2060     12   31  0.716525
# 8781  2060-12-31 21:00:00  2060-12-31 21:00:00  2060     12   31  0.783441
# 8782  2060-12-31 22:00:00  2060-12-31 22:00:00  2060     12   31  0.023411
# 8783  2060-12-31 23:00:00  2060-12-31 23:00:00  2060     12   31  0.113730
#
#        sazonal  timeSeries
# 0     1.000000   10.422338
# ...

# %%
plt.plot(allDataDf['datetime'],allDataDf['timeSeries'])
#plotagem do df total acima
#primeiro o eixo x = datetime
#depois o eixo y = timeseries
